# %%
#Dosya yüklemeyi sağlıyor
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1c52aa1-11a4-404a-80bc-2de41e72213d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1c52aa1-11a4-404a-80bc-2de41e72213d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd # pandas kütüphanesini "pd" takma adıyla aktarıyor
dosya = pd.read_csv("malicious_phish.csv")
dosya.head(10) # Belirtilen csv dosyasının ilk 10 satırını gösterir
# Out:
#                                                  url        type
# 0                                   br-icloud.com.br    phishing
# 1                mp3raid.com/music/krizz_kaliko.html      benign
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement
# 5  http://buzzfil.net/m/show-art/ils-etaient-loin...      benign
# 6      espn.go.com/nba/player/_/id/3457/brandon-rush      benign
# 7     yourbittorrent.com/?q=anthony-hamilton-soulife      benign
# 8       http://www.pashminaonline.com/pure-pashminas  defacement
# 9      allmusic.com/album/crazy-from-the-heat-r16990      benign

# %%
dosya = pd.read_csv("malicious_phish.csv")
dosya.tail(10) # Belirtilen csv dosyasının son 10 satırını gösterir
# Out:
#                                                   url      type
# 651181        www.1up.com/do/gameOverview?cId=3159391  phishing
# 651182         psx.ign.com/articles/131/131835p1.html  phishing
# 651183           wii.gamespy.com/wii/cursed-mountain/  phishing
# 651184          wii.ign.com/objects/142/14270799.html  phishing
# 651185       xbox360.gamespy.com/xbox-360/dead-space/  phishing
# 651186        xbox360.ign.com/objects/850/850402.html  phishing
# 651187   games.teamxbox.com/xbox-360/1860/Dead-Space/  phishing
# 651188     www.gamespot.com/xbox360/action/deadspace/  phishing
# 651189  en.wikipedia.org/wiki/Dead_Space_(video_game)  phishing
# 651190      www.angelfire.com/goth/devilmaycrytonite/  phishing

# %%
dosya = pd.read_csv("malicious_phish.csv")
dosya.info() #Belirtilen csv dosyasının özet halinde bilgilerini gösteriyor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651191 entries, 0 to 651190
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   url     651191 non-null  object
#  1   type    651191 non-null  object
# dtypes: object(2)
# memory usage: 9.9+ MB

# %%
dosya = pd.read_csv("malicious_phish.csv")
dosya['type'].value_counts() # 'type' adlı sütündaki değerlerin sayısını sayıp değerlerin tekrarlanma durumunu gösteriyor
# Out:
# benign        428103
# defacement     96457
# phishing       94111
# malware        32520
# Name: type, dtype: int64

# %%
dosya = pd.read_csv("malicious_phish.csv")
dosya['url'].value_counts() # 'url' adlı sütundaki değerlerin sayısını sayarak URL'lerin tekrarlanma durumunu gösteriyor
# Out:
# http://style.org.hc360.com/css/detail/mysite/siteconfig/pro_control.css                         180
# http://www.pubyun.com/wiki/lib/exe/css.php?t=dokuwiki&tseed=f1f16e8c6142fab8553f2b9cfe045961    146
# http://9779.info/%E6%A0%91%E5%8F%B6%E8%B4%B4%E7%94%BB%E4%BD%9C%E5%93%81/                         91
# http://9779.info/%E6%A0%91%E5%8F%B6%E7%B2%98%E8%B4%B4%E7%94%BB/                                  88
# http://www.js182.com/app/member/SportOption.php?uid=guest&langx=gb                               79
#                                                                                                ...
# en.wikipedia.org/wiki/Montrealer                                                                  1
# redbulgaria.com/                                                                                  1
# news.ontario.ca/opo/en/2011/06/highway-417-expansion-moving-forward.html                          1
# ...

# %%
dosya = pd.read_csv("malicious_phish.csv")
dosya = dosya.drop_duplicates(subset='url', keep='first') #'url' sütunundaki tekrar eden satırları kaldırır
dosya.isnull().sum() # Dosyanın içindeki eksik değerlerin sayısını toplayarak getiriyor
# Out:
# url     0
# type    0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression() # Model oluşturuluyor

a = veri['url'] # 'a' değişkenine 'url' sütununu atıyor
b = veri['type'] # 'b' değişkenine 'type' sütununu atıyor

from sklearn.model_selection import train_test_split
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.2, random_state=42)
# Verileri eğitim ve test olmak üzere iki kümeye ayırır
# test_size=0.2 kısmı veri kümesinin %20'sinin test verisi olarak ayrılacağını gösterir
# random_state=42 kısmı rastgele bölmelerin her seferinde aynı olmasını sağlar

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
# Metin verilerini sayısal vektörlere dönüştürmek için kullanılır

model.fit(a_train_tfidf, b_train)
# Model eğitilir

a_train_tfidf = vectorizer.fit_transform(a_train)
a_test_tfidf = vectorizer.transform(a_test)
b_train_tfidf = vectorizer.fit_transform(b_train)
b_test_tfidf = vectorizer.transform(b_test)
# Eğitim verileri için TfidfVectorizer kullanarak dönüştürme yapılır

b_pred = model.predict(a_test_tfidf)
# Test verileri üzerinde tahmin yapılır

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(b_test, b_pred)
print("Model Başarı Oranı:", accuracy)
# Başarı oranı hesaplanır
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model Başarı Oranı: 0.9453222485650112
